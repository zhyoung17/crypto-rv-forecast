# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import StandardScaler

data = pd.read_csv("../../data/ethusd_lasso_selected.csv")
data['time'] = pd.to_datetime(data['time'])
#remove NaN values
data = data.dropna()
data.head()
garch_train= pd.read_csv("../../results/models/GARCH_in_sample.csv") #2016-06-12 to 2022-04-29
garch_test = pd.read_csv("../../results/models/untuned_GARCH_predictions.csv") #2022-04-30 to 2023-10-08
garch_test = garch_test.rename(columns={'0':'Predicted Volatility'})
garch_train['time'] = pd.to_datetime(garch_train['time'])
garch_test['time'] = pd.to_datetime(garch_test['time'])
garch = pd.concat([garch_train, garch_test])
garch['time'] = pd.to_datetime(garch['time'])
#inner join to get the same time period
data = pd.merge(data, garch, on='time', how='inner')
data = data.set_index('time')
#rename columns
data = data.rename(columns={'Predicted Volatility':'garch'})
data = data.dropna()

# %% [markdown]
# # feature engineering

# %%
# Define features & target
all_features = data.columns.tolist()
to_remove = ['time',  'open','daily_return' ,'RV_d,t', 'RV_w,t', 'RV_m,t']
features = [f for f in all_features if f not in to_remove]
target = 'ln_RV_d,t'  # Predicting next day's realized variance

# 2️⃣ Create Input Sequences for LSTM
def create_sequences(data, lookback=60):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i+lookback])  # Past 60 days as input
        y.append(data[i+lookback, 0])  # Predicting next day's realized variance
    return np.array(X), np.array(y)

# Convert DataFrame to NumPy array for sequence creation
data_values = data[features].values
lookback = 60  # Use 60-day rolling window

# Create sequences
X, y = create_sequences(data_values, lookback)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow import keras

# Train-Test Split
#train is from  #2016-06-12 to 2022-04-26, test is from 2022-04-27 to 2023-10-08, as pre-determined from the GARCH model outputs

X_train, X_test = X[:len(data)-len(garch_test)], X[len(data)-len(garch_test):]
y_train, y_test = y[:len(data)-len(garch_test)], y[len(data)-len(garch_test):]

scaler_X = StandardScaler()
scaler_y = StandardScaler()

# Convert train data into correct shape
X_train = scaler_X.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test = scaler_X.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
y_train = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten() 
y_test = scaler_y.transform(y_test.reshape(-1, 1)).flatten()

# Further split training into training & validation (80% train, 20% validation)
val_size = int(len(X_train) * 0.2)  # 20% of training data
X_val, y_val = X_train[-val_size:], y_train[-val_size:]  # Last 20% for validation
X_train, y_train = X_train[:-val_size], y_train[:-val_size]  # Remaining for training

print("Training Set:", X_train.shape, y_train.shape)
print("Validation Set:", X_val.shape, y_val.shape)
print("Test Set:", X_test.shape, y_test.shape)
# Out:
# Training Set: (1672, 60, 10) (1672,)
# Validation Set: (418, 60, 10) (418,)
# Test Set: (463, 60, 10) (463,)

# %%
# Define LSTM Model
model = Sequential([
    Input(shape=(lookback, len(features))),
    LSTM(256, return_sequences=True, activation='tanh', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    Dropout(0.2),
    LSTM(128, return_sequences=True, activation='tanh'), 
    Dropout(0.1),
    LSTM(64, return_sequences=True, activation='tanh'), 
    Dropout(0.1),
    LSTM(64, return_sequences=True, activation='tanh'), 
    Dropout(0.2),
    LSTM(64, return_sequences=False, activation='tanh'), 
    Dropout(0.1),
    Dense(1, activation=None)
])

model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate=0.001), #set learning rate to half of default
    loss='mse',
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(),
             tf.keras.metrics.RootMeanSquaredError()]
)

# Train the LSTM Model
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3) #early stopping functionality
history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=15, batch_size=16, verbose=1,
                    callbacks=[callback])

# Save the model
model.save('../../results/models/garch-lstm_model.keras')
# Out:
# Epoch 1/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 89ms/step - loss: 0.7318 - mean_absolute_percentage_error: 156.7241 - root_mean_squared_error: 0.8418 - val_loss: 0.4546 - val_mean_absolute_percentage_error: 191.9222 - val_root_mean_squared_error: 0.6636
# Epoch 2/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 94ms/step - loss: 0.5367 - mean_absolute_percentage_error: 190.4742 - root_mean_squared_error: 0.7231 - val_loss: 0.4206 - val_mean_absolute_percentage_error: 300.1457 - val_root_mean_squared_error: 0.6401
# Epoch 3/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step - loss: 0.4556 - mean_absolute_percentage_error: 219.9251 - root_mean_squared_error: 0.6667 - val_loss: 0.3753 - val_mean_absolute_percentage_error: 191.4365 - val_root_mean_squared_error: 0.6050
# Epoch 4/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step - loss: 0.4182 - mean_absolute_percentage_error: 177.5365 - root_mean_squared_error: 0.6388 - val_loss: 0.3280 - val_mean_absolute_percentage_error: 233.4785 - val_root_mean_squared_error: 0.5652
# Epoch 5/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - loss: 0.3854 - mean_absolute_percentage_error: 160.3206 - root_mean_squared_error: 0.6135 - val_loss: 0.3729 - val_mean_absolute_percentage_error: 548.7223 - val_root_mean_squared_error: 0.6038
# Epoch 6/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - loss: 0.4006 - mean_absolute_percentage_error: 143.7165 - root_mean_squared_error: 0.6262 - val_loss: 0.4180 - val_mean_absolute_percentage_error: 399.7895 - val_root_mean_squared_error: 0.6401
# Epoch 7/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - loss: 0.3493 - mean_absolute_percentage_error: 319.9042 - root_mean_squared_error: 0.5839 - val_loss: 0.2711 - val_mean_absolute_percentage_error: 344.2342 - val_root_mean_squared_error: 0.5128
# Epoch 8/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - loss: 0.3382 - mean_absolute_percentage_error: 138.6135 - root_mean_squared_error: 0.5743 - val_loss: 0.2730 - val_mean_absolute_percentage_error: 283.9940 - val_root_mean_squared_error: 0.5148
# Epoch 9/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 92ms/step - loss: 0.3329 - mean_absolute_percentage_error: 139.2294 - root_mean_squared_error: 0.5698 - val_loss: 0.2659 - val_mean_absolute_percentage_error: 325.3590 - val_root_mean_squared_error: 0.5079
# Epoch 10/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - loss: 0.3247 - mean_absolute_percentage_error: 224.1255 - root_mean_squared_error: 0.5620 - val_loss: 0.2775 - val_mean_absolute_percentage_error: 419.1217 - val_root_mean_squared_error: 0.5193
# Epoch 11/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 94ms/step - loss: 0.3353 - mean_absolute_percentage_error: 143.2855 - root_mean_squared_error: 0.5720 - val_loss: 0.3596 - val_mean_absolute_percentage_error: 350.2385 - val_root_mean_squared_error: 0.5932
# Epoch 12/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - loss: 0.3237 - mean_absolute_percentage_error: 147.7434 - root_mean_squared_error: 0.5618 - val_loss: 0.2906 - val_mean_absolute_percentage_error: 313.0425 - val_root_mean_squared_error: 0.5317

# %%
# Load model
model = keras.models.load_model('../../results/models/garch_lstm_best_model.keras')

# Rolling Forecast for Test Set
predictions = []
history = np.array(X_train[-1])  # Convert last training window to numpy array

for i in range(len(X_test)):
    # Predict the next day's realized variance
    pred = model.predict(history.reshape(1, lookback, len(features)), verbose = 0)[0, 0]
    predictions.append(pred)

    # Use actual `y_test[i]` instead of `pred` for updating the rolling window
    new_entry = np.hstack([y_test[i], history[-1, 1:]])  # Keep actual value, retain other feature values
    history = np.vstack([history[1:], new_entry])  # Remove oldest, add new actual value

# Convert predictions back from log-scale
predictions = scaler_y.inverse_transform(np.array(predictions).reshape(-1, 1))
predictions = np.exp(predictions) 

# Save Predictions
results = pd.DataFrame({
    'time': data.index[len(data)-len(garch_test) + lookback:], 
    'RV_forecast': predictions.flatten()
})
results.to_csv("../../results/models/garch-lstm_forecast.csv", index=False)

print("One-day rolling forecast completed and saved!")
# Out:
# One-day rolling forecast completed and saved!

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score
import matplotlib.pyplot as plt

# Load test set and inverse transform
test_actual = np.exp(scaler_y.inverse_transform(y_test.reshape(-1, 1)))[10:] 

# Load LSTM Forecasts
forecast_df = pd.read_csv("../../results/models/garch-lstm_forecast.csv")
lstm_predictions = forecast_df["RV_forecast"].values[10:]


# Calculate Error Metrics
mse = mean_squared_error(test_actual, lstm_predictions)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(test_actual, lstm_predictions)
r2 = r2_score(test_actual, lstm_predictions)

# Print evaluation metrics
print(f"🔹 Mean Squared Error (MSE): {mse:.6f}")
print(f"🔹 Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"🔹 Mean Absolute Percentage Error (MAPE): {mape:.6%}")
print(f"🔹 R² Score: {r2:.6f}")

# Plot Actual vs Predicted Realized Variance
plt.figure(figsize=(12,6))
plt.plot(data.index[-len(test_actual):], test_actual, label="Actual RV", color="blue", alpha=0.7)  # ✅ Ensure time index matches test size
plt.plot(data.index[-len(test_actual):], lstm_predictions, label="LSTM Forecast", color="red", linestyle="dashed")

plt.xlabel("Date")
plt.ylabel("Realized Variance")
plt.title(f"LSTM Forecast ({lookback}-day lookback) vs Actual Realized Variance")
plt.legend()

# Add Captions
plt.figtext(0.5, 0.01, f"MAPE: {mape:.6%} | RMSE: {rmse:.6f} | R²: {r2:.6f}", wrap=True, horizontalalignment='center', fontsize=12)

# Save Before Showing Plot
plt.savefig(f'../../results/figures/garch-lstm_forecast_plot_{lookback}_lookback.png')
plt.show()
# Out:
# 🔹 Mean Squared Error (MSE): 0.000002
# 🔹 Root Mean Squared Error (RMSE): 0.001386
# 🔹 Mean Absolute Percentage Error (MAPE): 157.197445%
# 🔹 R² Score: 0.218954

# %%
import keras_tuner as kt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.regularizers import l2

def build_model(hp):
    model = Sequential()
    model.add(Input(shape=(lookback, len(features))))
    
    # Select the number of LSTM layers (2, 3, or 4)
    num_layers = hp.Choice('num_layers', [3, 4,5])
    
    # Define first LSTM layer size
    first_layer_units = hp.Choice('lstm_units_0', [128, 256]) 
    model.add(LSTM(
        units=first_layer_units,
        return_sequences=True,  
        activation='tanh',
        kernel_regularizer=l2(0.001)  # Regularize only the first layer
    ))
    model.add(Dropout(hp.Choice('dropout_0', [0.1, 0.2])))

    # Add remaining layers with non-increasing units
    previous_units = first_layer_units  # Track previous layer units
    for i in range(1, num_layers):
        available_units = [u for u in [64, 128, 256] if u <= previous_units]  # Only allow non-increasing sizes
        current_units = hp.Choice(f'lstm_units_{i}', available_units)

        model.add(LSTM(
            units=current_units,
            return_sequences=True if i < num_layers - 1 else False,  
            activation='tanh'
        ))
        model.add(Dropout(hp.Choice(f'dropout_{i}', [0.1, 0.2])))

        previous_units = current_units  # Update tracking variable

    model.add(Dense(1, activation=None))  # Output layer

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='mse',
        metrics=[tf.keras.metrics.MeanAbsolutePercentageError(), tf.keras.metrics.RootMeanSquaredError()]
    )

    return model

# Define the tuner (Random Search with 10 trials)
tuner = kt.RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=30,  # Number of models to test
    executions_per_trial=1,  
    directory='garch_lstm_tuning_results',
    project_name='garch_lstm_hyperparameter_tuning_new',
    overwrite=False
)

# Perform Hyperparameter Tuning with Early Stopping
tuner.search(X_train, y_train, validation_data=(X_val, y_val), epochs=10, batch_size=16, 
             callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)])

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
✅ Best Hyperparameters:
- LSTM Layers: {best_hps.get('num_layers')}
- LSTM Units per Layer: {[best_hps.get(f'lstm_units_{i}') for i in range(best_hps.get("num_layers"))]}
- Dropout Rates: {[best_hps.get(f'dropout_{i}') for i in range(best_hps.get("num_layers"))]}
""")

# Train the best model
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, batch_size=16, verbose=1, 
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)])

# Save the best model
best_model.save('../../results/models/garch_lstm_best_model.keras')

print("✅ Hyperparameter tuning complete! Best model saved.")
# Out:
# Trial 30 Complete [00h 00m 57s]
# val_loss: 0.28162094950675964
#
# Best val_loss So Far: 0.24588370323181152
# Total elapsed time: 00h 40m 14s
#
# ✅ Best Hyperparameters:
# - LSTM Layers: 3
# - LSTM Units per Layer: [128, 128, 64]
# - Dropout Rates: [0.1, 0.1, 0.1]
#
# Epoch 1/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 0.6201 - mean_absolute_percentage_error: 161.1792 - root_mean_squared_error: 0.7722 - val_loss: 0.4141 - val_mean_absolute_percentage_error: 325.3622 - val_root_mean_squared_error: 0.6304
# Epoch 2/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.4060 - mean_absolute_percentage_error: 145.5400 - root_mean_squared_error: 0.6225 - val_loss: 0.3326 - val_mean_absolute_percentage_error: 226.0821 - val_root_mean_squared_error: 0.5640
# Epoch 3/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.4255 - mean_absolute_percentage_error: 149.4147 - root_mean_squared_error: 0.6409 - val_loss: 0.3168 - val_mean_absolute_percentage_error: 287.0775 - val_root_mean_squared_error: 0.5513
# Epoch 4/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.3733 - mean_absolute_percentage_error: 145.2115 - root_mean_squared_error: 0.6005 - val_loss: 0.3098 - val_mean_absolute_percentage_error: 228.0698 - val_root_mean_squared_error: 0.5459
# Epoch 5/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.3453 - mean_absolute_percentage_error: 122.9503 - root_mean_squared_error: 0.5773 - val_loss: 0.3092 - val_mean_absolute_percentage_error: 242.2503 - val_root_mean_squared_error: 0.5461
# Epoch 6/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.3402 - mean_absolute_percentage_error: 154.0085 - root_mean_squared_error: 0.5735 - val_loss: 0.2837 - val_mean_absolute_percentage_error: 276.7203 - val_root_mean_squared_error: 0.5231
# Epoch 7/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.3437 - mean_absolute_percentage_error: 188.1169 - root_mean_squared_error: 0.5767 - val_loss: 0.3045 - val_mean_absolute_percentage_error: 304.6534 - val_root_mean_squared_error: 0.5432
# Epoch 8/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.3252 - mean_absolute_percentage_error: 141.0678 - root_mean_squared_error: 0.5618 - val_loss: 0.2736 - val_mean_absolute_percentage_error: 284.0157 - val_root_mean_squared_error: 0.5146
# Epoch 9/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.3333 - mean_absolute_percentage_error: 226.0583 - root_mean_squared_error: 0.5691 - val_loss: 0.3027 - val_mean_absolute_percentage_error: 305.5292 - val_root_mean_squared_error: 0.5426
# Epoch 10/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.3090 - mean_absolute_percentage_error: 145.9048 - root_mean_squared_error: 0.5479 - val_loss: 0.2466 - val_mean_absolute_percentage_error: 314.5193 - val_root_mean_squared_error: 0.4884
# Epoch 11/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.3031 - mean_absolute_percentage_error: 138.8536 - root_mean_squared_error: 0.5429 - val_loss: 0.2717 - val_mean_absolute_percentage_error: 340.5099 - val_root_mean_squared_error: 0.5137
# Epoch 12/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.3183 - mean_absolute_percentage_error: 141.5689 - root_mean_squared_error: 0.5571 - val_loss: 0.2480 - val_mean_absolute_percentage_error: 291.0387 - val_root_mean_squared_error: 0.4904
# Epoch 13/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.3091 - mean_absolute_percentage_error: 158.7508 - root_mean_squared_error: 0.5488 - val_loss: 0.2646 - val_mean_absolute_percentage_error: 273.1305 - val_root_mean_squared_error: 0.5073
# ✅ Hyperparameter tuning complete! Best model saved.

# %%
best_hps_list = tuner.get_best_hyperparameters(num_trials=3)
for best_hps in best_hps_list:
    print(f"""
    ✅ Best Hyperparameters:
    - LSTM Layers: {best_hps.get('num_layers')}
    - LSTM Units per Layer: {[best_hps.get(f'lstm_units_{i}') for i in range(best_hps.get("num_layers"))]}
    - Dropout Rates: {[best_hps.get(f'dropout_{i}') for i in range(best_hps.get("num_layers"))]}
    """)
# Out:
#     ✅ Best Hyperparameters:
#     - LSTM Layers: 3
#     - LSTM Units per Layer: [128, 128, 64]
#     - Dropout Rates: [0.1, 0.1, 0.1]
#
#
#     ✅ Best Hyperparameters:
#     - LSTM Layers: 4
#     - LSTM Units per Layer: [256, 128, 64, 64]
#     - Dropout Rates: [0.2, 0.2, 0.1, 0.2]
#
#
#     ✅ Best Hyperparameters:
#     - LSTM Layers: 4
#     - LSTM Units per Layer: [128, 128, 64, 64]
#     - Dropout Rates: [0.2, 0.1, 0.2, 0.1]
