# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import StandardScaler

data = pd.read_csv("../../data/ethusd_lasso_selected.csv")
data['time'] = pd.to_datetime(data['time'])
#remove NaN values
data = data.dropna()
data.head()
garch_train= pd.read_csv("../../results/models/GARCH_in_sample.csv") #2016-06-12 to 2022-04-26
garch_test = pd.read_csv("../../results/models/GARCH_predictions.csv") #2022-04-27 to 2023-10-08
garch = pd.concat([garch_train, garch_test])
garch['time'] = pd.to_datetime(garch['time'])
#inner join to get the same time period
data = pd.merge(data, garch, on='time', how='inner')
data = data.set_index('time')
#rename columns
data = data.rename(columns={'Predicted Volatility':'garch'})

# %% [markdown]
# # feature engineering

# %%
# Define features & target
all_features = data.columns.tolist()
to_remove = ['time',  'open','daily_return' ,'RV_d,t', 'RV_w,t', 'RV_m,t']
features = [f for f in all_features if f not in to_remove]
target = 'ln_RV_d,t'  # Predicting next day's realized variance

# 2️⃣ Create Input Sequences for LSTM
def create_sequences(data, lookback=60):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i+lookback])  # Past 60 days as input
        y.append(data[i+lookback, 0])  # Predicting next day's realized variance
    return np.array(X), np.array(y)

# Convert DataFrame to NumPy array for sequence creation
data_values = data[features].values
lookback = 60  # Use 60-day rolling window

# Create sequences
X, y = create_sequences(data_values, lookback)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow import keras

# Train-Test Split
#train is from  #2016-06-12 to 2022-04-26, test is from 2022-04-27 to 2023-10-08, as pre-determined from the GARCH model outputs

X_train, X_test = X[:len(data)-len(garch_test)], X[len(data)-len(garch_test):]
y_train, y_test = y[:len(data)-len(garch_test)], y[len(data)-len(garch_test):]

scaler_X = StandardScaler()
scaler_y = StandardScaler()

# Convert train data into correct shape
X_train = scaler_X.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test = scaler_X.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
y_train = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten() 
y_test = scaler_y.transform(y_test.reshape(-1, 1)).flatten()

# Further split training into training & validation (80% train, 20% validation)
val_size = int(len(X_train) * 0.2)  # 20% of training data
X_val, y_val = X_train[-val_size:], y_train[-val_size:]  # Last 20% for validation
X_train, y_train = X_train[:-val_size], y_train[:-val_size]  # Remaining for training

print("Training Set:", X_train.shape, y_train.shape)
print("Validation Set:", X_val.shape, y_val.shape)
print("Test Set:", X_test.shape, y_test.shape)

# Define LSTM Model
model = Sequential([
    Input(shape=(lookback, len(features))),
    LSTM(256, return_sequences=True, activation='tanh', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    Dropout(0.2),
    LSTM(64, return_sequences=True, activation='tanh'), 
    Dropout(0.2),
    LSTM(64, return_sequences=False, activation='tanh'), 
    Dropout(0.1),
    Dense(1, activation=None)
])

model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate=0.001), #set learning rate to half of default
    loss='mse',
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(),
             tf.keras.metrics.RootMeanSquaredError()]
)

# Train the LSTM Model
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3) #early stopping functionality
history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=15, batch_size=16, verbose=1,
                    callbacks=[callback])

# Save the model
model.save('../../results/models/garch-lstm_model.keras')
# Out:
# Training Set: (1687, 60, 8) (1687,)
# Validation Set: (421, 60, 8) (421,)
# Test Set: (468, 60, 8) (468,)
# Epoch 1/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - loss: 0.8478 - mean_absolute_percentage_error: 507.3432 - root_mean_squared_error: 0.9076 - val_loss: 0.4682 - val_mean_absolute_percentage_error: 129.4662 - val_root_mean_squared_error: 0.6743
# Epoch 2/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.5680 - mean_absolute_percentage_error: 292.7409 - root_mean_squared_error: 0.7443 - val_loss: 0.3819 - val_mean_absolute_percentage_error: 190.2084 - val_root_mean_squared_error: 0.6083
# Epoch 3/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 0.5131 - mean_absolute_percentage_error: 722.3434 - root_mean_squared_error: 0.7081 - val_loss: 0.3610 - val_mean_absolute_percentage_error: 211.4429 - val_root_mean_squared_error: 0.5919
# Epoch 4/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.4794 - mean_absolute_percentage_error: 705.4026 - root_mean_squared_error: 0.6846 - val_loss: 0.3455 - val_mean_absolute_percentage_error: 179.9543 - val_root_mean_squared_error: 0.5791
# Epoch 5/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.4330 - mean_absolute_percentage_error: 262.3488 - root_mean_squared_error: 0.6500 - val_loss: 0.3179 - val_mean_absolute_percentage_error: 200.9953 - val_root_mean_squared_error: 0.5552
# Epoch 6/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.4375 - mean_absolute_percentage_error: 442.4664 - root_mean_squared_error: 0.6539 - val_loss: 0.3185 - val_mean_absolute_percentage_error: 211.9209 - val_root_mean_squared_error: 0.5564
# Epoch 7/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.4433 - mean_absolute_percentage_error: 294.7847 - root_mean_squared_error: 0.6587 - val_loss: 0.3192 - val_mean_absolute_percentage_error: 243.5645 - val_root_mean_squared_error: 0.5575
# Epoch 8/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.4092 - mean_absolute_percentage_error: 651.5564 - root_mean_squared_error: 0.6324 - val_loss: 0.2958 - val_mean_absolute_percentage_error: 190.9957 - val_root_mean_squared_error: 0.5364
# Epoch 9/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.4115 - mean_absolute_percentage_error: 304.2368 - root_mean_squared_error: 0.6341 - val_loss: 0.2926 - val_mean_absolute_percentage_error: 189.1729 - val_root_mean_squared_error: 0.5336
# Epoch 10/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.4476 - mean_absolute_percentage_error: 551.7544 - root_mean_squared_error: 0.6630 - val_loss: 0.3191 - val_mean_absolute_percentage_error: 207.9384 - val_root_mean_squared_error: 0.5581
# Epoch 11/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.4470 - mean_absolute_percentage_error: 936.6982 - root_mean_squared_error: 0.6618 - val_loss: 0.3191 - val_mean_absolute_percentage_error: 247.7702 - val_root_mean_squared_error: 0.5581
# Epoch 12/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.4017 - mean_absolute_percentage_error: 328.4648 - root_mean_squared_error: 0.6270 - val_loss: 0.2961 - val_mean_absolute_percentage_error: 230.5487 - val_root_mean_squared_error: 0.5372

# %%
# Load model
model = keras.models.load_model('../../results/models/garch_lstm_best_model.keras')

# Rolling Forecast for Test Set
predictions = []
history = np.array(X_train[-1])  # Convert last training window to numpy array

for i in range(len(X_test)):
    # Predict the next day's realized variance
    pred = model.predict(history.reshape(1, lookback, len(features)), verbose = 0)[0, 0]
    predictions.append(pred)

    # Use actual `y_test[i]` instead of `pred` for updating the rolling window
    new_entry = np.hstack([y_test[i], history[-1, 1:]])  # Keep actual value, retain other feature values
    history = np.vstack([history[1:], new_entry])  # Remove oldest, add new actual value

# Convert predictions back from log-scale
predictions = scaler_y.inverse_transform(np.array(predictions).reshape(-1, 1))
predictions = np.exp(predictions) 

# Save Predictions
results = pd.DataFrame({
    'time': data.index[len(data)-len(garch_test) + lookback:], 
    'RV_forecast': predictions.flatten()
})
results.to_csv("../../results/models/garch-lstm_forecast.csv", index=False)

print("One-day rolling forecast completed and saved!")
# Out:
# One-day rolling forecast completed and saved!

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score
import matplotlib.pyplot as plt

# Load test set and inverse transform
test_actual = np.exp(scaler_y.inverse_transform(y_test.reshape(-1, 1)))[10:] 

# Load LSTM Forecasts
forecast_df = pd.read_csv("../../results/models/garch-lstm_forecast.csv")
lstm_predictions = forecast_df["RV_forecast"].values[10:]


# Calculate Error Metrics
mse = mean_squared_error(test_actual, lstm_predictions)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(test_actual, lstm_predictions)
r2 = r2_score(test_actual, lstm_predictions)

# Print evaluation metrics
print(f"🔹 Mean Squared Error (MSE): {mse:.6f}")
print(f"🔹 Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"🔹 Mean Absolute Percentage Error (MAPE): {mape:.6%}")
print(f"🔹 R² Score: {r2:.6f}")

# Plot Actual vs Predicted Realized Variance
plt.figure(figsize=(12,6))
plt.plot(data.index[-len(test_actual):], test_actual, label="Actual RV", color="blue", alpha=0.7)  # ✅ Ensure time index matches test size
plt.plot(data.index[-len(test_actual):], lstm_predictions, label="LSTM Forecast", color="red", linestyle="dashed")

plt.xlabel("Date")
plt.ylabel("Realized Variance")
plt.title(f"LSTM Forecast ({lookback}-day lookback) vs Actual Realized Variance")
plt.legend()

# Add Captions
plt.figtext(0.5, 0.01, f"MAPE: {mape:.6%} | RMSE: {rmse:.6f} | R²: {r2:.6f}", wrap=True, horizontalalignment='center', fontsize=12)

# Save Before Showing Plot
plt.savefig(f'../../results/figures/garch-lstm_forecast_plot_{lookback}_lookback.png')
plt.show()
# Out:
# 🔹 Mean Squared Error (MSE): 0.000002
# 🔹 Root Mean Squared Error (RMSE): 0.001268
# 🔹 Mean Absolute Percentage Error (MAPE): 188.488296%
# 🔹 R² Score: 0.337987

# %%
import keras_tuner as kt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.regularizers import l2

def build_model(hp):
    model = Sequential()
    model.add(Input(shape=(lookback, len(features))))
    
    # Select the number of LSTM layers (2, 3, or 4)
    num_layers = hp.Choice('num_layers', [3, 4])
    
    # Define first LSTM layer size
    first_layer_units = hp.Choice('lstm_units_0', [64, 128, 256]) 
    model.add(LSTM(
        units=first_layer_units,
        return_sequences=True,  
        activation='tanh',
        kernel_regularizer=l2(0.001)  # Regularize only the first layer
    ))
    model.add(Dropout(hp.Choice('dropout_0', [0.1, 0.2])))

    # Add remaining layers with non-increasing units
    previous_units = first_layer_units  # Track previous layer units
    for i in range(1, num_layers):
        available_units = [u for u in [64, 128, 256] if u <= previous_units]  # Only allow non-increasing sizes
        current_units = hp.Choice(f'lstm_units_{i}', available_units)

        model.add(LSTM(
            units=current_units,
            return_sequences=True if i < num_layers - 1 else False,  
            activation='tanh'
        ))
        model.add(Dropout(hp.Choice(f'dropout_{i}', [0.1, 0.2])))

        previous_units = current_units  # Update tracking variable

    model.add(Dense(1, activation=None))  # Output layer

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='mse',
        metrics=[tf.keras.metrics.MeanAbsolutePercentageError(), tf.keras.metrics.RootMeanSquaredError()]
    )

    return model

# Define the tuner (Random Search with 10 trials)
tuner = kt.RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=30,  # Number of models to test
    executions_per_trial=1,  
    directory='garch_lstm_tuning_results',
    project_name='lstm_hyperparameter_tuning',
    overwrite=False
)

# Perform Hyperparameter Tuning with Early Stopping
tuner.search(X_train, y_train, validation_data=(X_val, y_val), epochs=10, batch_size=16, 
             callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)])

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
✅ Best Hyperparameters:
- LSTM Layers: {best_hps.get('num_layers')}
- LSTM Units per Layer: {[best_hps.get(f'lstm_units_{i}') for i in range(best_hps.get("num_layers"))]}
- Dropout Rates: {[best_hps.get(f'dropout_{i}') for i in range(best_hps.get("num_layers"))]}
""")

# Train the best model
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=15, batch_size=16, verbose=1, 
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)])

# Save the best model
best_model.save('../../results/models/garch_lstm_best_model.keras')

print("✅ Hyperparameter tuning complete! Best model saved.")
# Out:
# Trial 30 Complete [00h 00m 28s]
# val_loss: 0.32895076274871826
#
# Best val_loss So Far: 0.2890860438346863
# Total elapsed time: 00h 34m 08s
#
# ✅ Best Hyperparameters:
# - LSTM Layers: 3
# - LSTM Units per Layer: [256, 64, 64]
# - Dropout Rates: [0.2, 0.2, 0.2]
#
# Epoch 1/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.8198 - mean_absolute_percentage_error: 359.3463 - root_mean_squared_error: 0.8945 - val_loss: 0.4477 - val_mean_absolute_percentage_error: 145.5073 - val_root_mean_squared_error: 0.6593
# Epoch 2/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.5681 - mean_absolute_percentage_error: 662.4579 - root_mean_squared_error: 0.7450 - val_loss: 0.3838 - val_mean_absolute_percentage_error: 181.9449 - val_root_mean_squared_error: 0.6103
# Epoch 3/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.5637 - mean_absolute_percentage_error: 321.2449 - root_mean_squared_error: 0.7429 - val_loss: 0.3551 - val_mean_absolute_percentage_error: 176.8890 - val_root_mean_squared_error: 0.5871
# Epoch 4/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.5059 - mean_absolute_percentage_error: 266.9656 - root_mean_squared_error: 0.7035 - val_loss: 0.3339 - val_mean_absolute_percentage_error: 204.0259 - val_root_mean_squared_error: 0.5690
# Epoch 5/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.4854 - mean_absolute_percentage_error: 317.3725 - root_mean_squared_error: 0.6886 - val_loss: 0.3466 - val_mean_absolute_percentage_error: 236.7509 - val_root_mean_squared_error: 0.5804
# Epoch 6/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.4411 - mean_absolute_percentage_error: 262.7604 - root_mean_squared_error: 0.6566 - val_loss: 0.3053 - val_mean_absolute_percentage_error: 197.1150 - val_root_mean_squared_error: 0.5440
# Epoch 7/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.4125 - mean_absolute_percentage_error: 321.7134 - root_mean_squared_error: 0.6348 - val_loss: 0.3150 - val_mean_absolute_percentage_error: 220.6358 - val_root_mean_squared_error: 0.5534
# Epoch 8/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.4232 - mean_absolute_percentage_error: 351.9962 - root_mean_squared_error: 0.6437 - val_loss: 0.3052 - val_mean_absolute_percentage_error: 216.4743 - val_root_mean_squared_error: 0.5447
# Epoch 9/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.4381 - mean_absolute_percentage_error: 320.9246 - root_mean_squared_error: 0.6548 - val_loss: 0.3025 - val_mean_absolute_percentage_error: 233.8749 - val_root_mean_squared_error: 0.5424
# Epoch 10/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.4181 - mean_absolute_percentage_error: 278.5639 - root_mean_squared_error: 0.6400 - val_loss: 0.3054 - val_mean_absolute_percentage_error: 196.7952 - val_root_mean_squared_error: 0.5455
# Epoch 11/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.4401 - mean_absolute_percentage_error: 324.7910 - root_mean_squared_error: 0.6566 - val_loss: 0.3005 - val_mean_absolute_percentage_error: 229.3893 - val_root_mean_squared_error: 0.5411
# Epoch 12/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.3999 - mean_absolute_percentage_error: 492.4333 - root_mean_squared_error: 0.6259 - val_loss: 0.2890 - val_mean_absolute_percentage_error: 219.4965 - val_root_mean_squared_error: 0.5304
# Epoch 13/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.3813 - mean_absolute_percentage_error: 271.9298 - root_mean_squared_error: 0.6105 - val_loss: 0.2929 - val_mean_absolute_percentage_error: 241.3563 - val_root_mean_squared_error: 0.5341
# Epoch 14/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.4150 - mean_absolute_percentage_error: 999.8189 - root_mean_squared_error: 0.6367 - val_loss: 0.2864 - val_mean_absolute_percentage_error: 209.6723 - val_root_mean_squared_error: 0.5279
# Epoch 15/15
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.4227 - mean_absolute_percentage_error: 317.1533 - root_mean_squared_error: 0.6440 - val_loss: 0.2942 - val_mean_absolute_percentage_error: 232.7430 - val_root_mean_squared_error: 0.5353
# ✅ Hyperparameter tuning complete! Best model saved.
