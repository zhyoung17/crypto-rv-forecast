# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import StandardScaler

data = pd.read_csv("../../data/ethusd_lasso_selected.csv")
data['time'] = pd.to_datetime(data['time'])
#remove NaN values
data = data.dropna()
data.head()
garch_train= pd.read_csv("../../results/models/GARCH_in_sample.csv") #2016-06-12 to 2022-04-26
garch_test = pd.read_csv("../../results/models/GARCH_predictions.csv") #2022-04-27 to 2023-10-08
garch = pd.concat([garch_train, garch_test])
garch['time'] = pd.to_datetime(garch['time'])
#inner join to get the same time period
data = pd.merge(data, garch, on='time', how='inner')
data = data.set_index('time')
#rename columns
data = data.rename(columns={'Predicted Volatility':'garch'})

# %% [markdown]
# # feature engineering

# %%
# Define features & target
all_features = data.columns.tolist()
to_remove = ['time',  'open','daily_return' ,'RV_d,t', 'RV_w,t', 'RV_m,t']
features = [f for f in all_features if f not in to_remove]
target = 'ln_RV_d,t'  # Predicting next day's realized variance

# 2️⃣ Create Input Sequences for LSTM
def create_sequences(data, lookback=60):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i+lookback])  # Past 60 days as input
        y.append(data[i+lookback, 0])  # Predicting next day's realized variance
    return np.array(X), np.array(y)

# Convert DataFrame to NumPy array for sequence creation
data_values = data[features].values
lookback = 60  # Use 60-day rolling window

# Create sequences
X, y = create_sequences(data_values, lookback)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow import keras

# Train-Test Split
#train is from  #2016-06-12 to 2022-04-26, test is from 2022-04-27 to 2023-10-08, as pre-determined from the GARCH model outputs

X_train, X_test = X[:len(data)-len(garch_test)], X[len(data)-len(garch_test):]
y_train, y_test = y[:len(data)-len(garch_test)], y[len(data)-len(garch_test):]

scaler_X = StandardScaler()
scaler_y = StandardScaler()

# Convert train data into correct shape
X_train = scaler_X.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test = scaler_X.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
y_train = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten() 
y_test = scaler_y.transform(y_test.reshape(-1, 1)).flatten()

# Further split training into training & validation (80% train, 20% validation)
val_size = int(len(X_train) * 0.2)  # 20% of training data
X_val, y_val = X_train[-val_size:], y_train[-val_size:]  # Last 20% for validation
X_train, y_train = X_train[:-val_size], y_train[:-val_size]  # Remaining for training

print("Training Set:", X_train.shape, y_train.shape)
print("Validation Set:", X_val.shape, y_val.shape)
print("Test Set:", X_test.shape, y_test.shape)

# Define LSTM Model
model = Sequential([
    Input(shape=(lookback, len(features))),
    LSTM(256, return_sequences=True, activation='tanh', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    Dropout(0.2),
    LSTM(64, return_sequences=True, activation='tanh'), 
    Dropout(0.2),
    LSTM(64, return_sequences=False, activation='tanh'), 
    Dropout(0.1),
    Dense(1, activation=None)
])

model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate=0.001), #set learning rate to half of default
    loss='mse',
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(),
             tf.keras.metrics.RootMeanSquaredError()]
)

# Train the LSTM Model
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3) #early stopping functionality
history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=15, batch_size=16, verbose=1,
                    callbacks=[callback])

# Save the model
model.save('../../results/models/garch-lstm_model.keras')
# Out:
# Training Set: (1669, 60, 10) (1669,)
# Validation Set: (417, 60, 10) (417,)
# Test Set: (468, 60, 10) (468,)
# Epoch 1/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - loss: 0.6461 - mean_absolute_percentage_error: 162.8257 - root_mean_squared_error: 0.7886 - val_loss: 0.3792 - val_mean_absolute_percentage_error: 279.8129 - val_root_mean_squared_error: 0.6024
# Epoch 2/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.4840 - mean_absolute_percentage_error: 158.2271 - root_mean_squared_error: 0.6837 - val_loss: 0.3337 - val_mean_absolute_percentage_error: 327.8063 - val_root_mean_squared_error: 0.5658
# Epoch 3/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 0.4144 - mean_absolute_percentage_error: 144.5463 - root_mean_squared_error: 0.6333 - val_loss: 0.3274 - val_mean_absolute_percentage_error: 302.2158 - val_root_mean_squared_error: 0.5618
# Epoch 4/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.3745 - mean_absolute_percentage_error: 139.4003 - root_mean_squared_error: 0.6020 - val_loss: 0.3478 - val_mean_absolute_percentage_error: 428.8923 - val_root_mean_squared_error: 0.5804
# Epoch 5/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 0.3831 - mean_absolute_percentage_error: 136.6805 - root_mean_squared_error: 0.6095 - val_loss: 0.2817 - val_mean_absolute_percentage_error: 347.5107 - val_root_mean_squared_error: 0.5209
# Epoch 6/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.3333 - mean_absolute_percentage_error: 148.7375 - root_mean_squared_error: 0.5682 - val_loss: 0.2822 - val_mean_absolute_percentage_error: 445.8124 - val_root_mean_squared_error: 0.5219
# Epoch 7/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.3469 - mean_absolute_percentage_error: 135.4550 - root_mean_squared_error: 0.5802 - val_loss: 0.2664 - val_mean_absolute_percentage_error: 380.1035 - val_root_mean_squared_error: 0.5072
# Epoch 8/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.3461 - mean_absolute_percentage_error: 136.1516 - root_mean_squared_error: 0.5803 - val_loss: 0.2648 - val_mean_absolute_percentage_error: 502.7418 - val_root_mean_squared_error: 0.5061
# Epoch 9/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 0.2924 - mean_absolute_percentage_error: 152.2527 - root_mean_squared_error: 0.5322 - val_loss: 0.2622 - val_mean_absolute_percentage_error: 579.5963 - val_root_mean_squared_error: 0.5040
# Epoch 10/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.3192 - mean_absolute_percentage_error: 146.8691 - root_mean_squared_error: 0.5574 - val_loss: 0.2761 - val_mean_absolute_percentage_error: 677.3060 - val_root_mean_squared_error: 0.5176
# Epoch 11/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.3038 - mean_absolute_percentage_error: 152.6835 - root_mean_squared_error: 0.5437 - val_loss: 0.2666 - val_mean_absolute_percentage_error: 666.0773 - val_root_mean_squared_error: 0.5085
# Epoch 12/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 0.3269 - mean_absolute_percentage_error: 141.0591 - root_mean_squared_error: 0.5644 - val_loss: 0.2647 - val_mean_absolute_percentage_error: 628.8666 - val_root_mean_squared_error: 0.5068

# %%
# Load model
model = keras.models.load_model('../../results/models/garch_lstm_best_model.keras')

# Rolling Forecast for Test Set
predictions = []
history = np.array(X_train[-1])  # Convert last training window to numpy array

for i in range(len(X_test)):
    # Predict the next day's realized variance
    pred = model.predict(history.reshape(1, lookback, len(features)), verbose = 0)[0, 0]
    predictions.append(pred)

    # Use actual `y_test[i]` instead of `pred` for updating the rolling window
    new_entry = np.hstack([y_test[i], history[-1, 1:]])  # Keep actual value, retain other feature values
    history = np.vstack([history[1:], new_entry])  # Remove oldest, add new actual value

# Convert predictions back from log-scale
predictions = scaler_y.inverse_transform(np.array(predictions).reshape(-1, 1))
predictions = np.exp(predictions) 

# Save Predictions
results = pd.DataFrame({
    'time': data.index[len(data)-len(garch_test) + lookback:], 
    'RV_forecast': predictions.flatten()
})
results.to_csv("../../results/models/garch-lstm_forecast.csv", index=False)

print("One-day rolling forecast completed and saved!")
# Out:
# One-day rolling forecast completed and saved!

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score
import matplotlib.pyplot as plt

# Load test set and inverse transform
test_actual = np.exp(scaler_y.inverse_transform(y_test.reshape(-1, 1)))[10:] 

# Load LSTM Forecasts
forecast_df = pd.read_csv("../../results/models/garch-lstm_forecast.csv")
lstm_predictions = forecast_df["RV_forecast"].values[10:]


# Calculate Error Metrics
mse = mean_squared_error(test_actual, lstm_predictions)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(test_actual, lstm_predictions)
r2 = r2_score(test_actual, lstm_predictions)

# Print evaluation metrics
print(f"🔹 Mean Squared Error (MSE): {mse:.6f}")
print(f"🔹 Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"🔹 Mean Absolute Percentage Error (MAPE): {mape:.6%}")
print(f"🔹 R² Score: {r2:.6f}")

# Plot Actual vs Predicted Realized Variance
plt.figure(figsize=(12,6))
plt.plot(data.index[-len(test_actual):], test_actual, label="Actual RV", color="blue", alpha=0.7)  # ✅ Ensure time index matches test size
plt.plot(data.index[-len(test_actual):], lstm_predictions, label="LSTM Forecast", color="red", linestyle="dashed")

plt.xlabel("Date")
plt.ylabel("Realized Variance")
plt.title(f"LSTM Forecast ({lookback}-day lookback) vs Actual Realized Variance")
plt.legend()

# Add Captions
plt.figtext(0.5, 0.01, f"MAPE: {mape:.6%} | RMSE: {rmse:.6f} | R²: {r2:.6f}", wrap=True, horizontalalignment='center', fontsize=12)

# Save Before Showing Plot
plt.savefig(f'../../results/figures/garch-lstm_forecast_plot_{lookback}_lookback.png')
plt.show()
# Out:
# 🔹 Mean Squared Error (MSE): 0.000002
# 🔹 Root Mean Squared Error (RMSE): 0.001321
# 🔹 Mean Absolute Percentage Error (MAPE): 141.742684%
# 🔹 R² Score: 0.288354

# %%
import keras_tuner as kt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.regularizers import l2

def build_model(hp):
    model = Sequential()
    model.add(Input(shape=(lookback, len(features))))
    
    # Select the number of LSTM layers (2, 3, or 4)
    num_layers = hp.Choice('num_layers', [3, 4])
    
    # Define first LSTM layer size
    first_layer_units = hp.Choice('lstm_units_0', [64, 128, 256]) 
    model.add(LSTM(
        units=first_layer_units,
        return_sequences=True,  
        activation='tanh',
        kernel_regularizer=l2(0.001)  # Regularize only the first layer
    ))
    model.add(Dropout(hp.Choice('dropout_0', [0.1, 0.2])))

    # Add remaining layers with non-increasing units
    previous_units = first_layer_units  # Track previous layer units
    for i in range(1, num_layers):
        available_units = [u for u in [64, 128, 256] if u <= previous_units]  # Only allow non-increasing sizes
        current_units = hp.Choice(f'lstm_units_{i}', available_units)

        model.add(LSTM(
            units=current_units,
            return_sequences=True if i < num_layers - 1 else False,  
            activation='tanh'
        ))
        model.add(Dropout(hp.Choice(f'dropout_{i}', [0.1, 0.2])))

        previous_units = current_units  # Update tracking variable

    model.add(Dense(1, activation=None))  # Output layer

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='mse',
        metrics=[tf.keras.metrics.MeanAbsolutePercentageError(), tf.keras.metrics.RootMeanSquaredError()]
    )

    return model

# Define the tuner (Random Search with 10 trials)
tuner = kt.RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=40,  # Number of models to test
    executions_per_trial=1,  
    directory='garch_lstm_tuning_results',
    project_name='lstm_hyperparameter_tuning_new',
    overwrite=False
)

# Perform Hyperparameter Tuning with Early Stopping
tuner.search(X_train, y_train, validation_data=(X_val, y_val), epochs=10, batch_size=16, 
             callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)])

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
✅ Best Hyperparameters:
- LSTM Layers: {best_hps.get('num_layers')}
- LSTM Units per Layer: {[best_hps.get(f'lstm_units_{i}') for i in range(best_hps.get("num_layers"))]}
- Dropout Rates: {[best_hps.get(f'dropout_{i}') for i in range(best_hps.get("num_layers"))]}
""")

# Train the best model
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=15, batch_size=16, verbose=1, 
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)])

# Save the best model
best_model.save('../../results/models/garch_lstm_best_model.keras')

print("✅ Hyperparameter tuning complete! Best model saved.")
# Out:
# Trial 40 Complete [00h 00m 27s]
# val_loss: 0.3153105676174164
#
# Best val_loss So Far: 0.25769761204719543
# Total elapsed time: 00h 31m 11s
#
# ✅ Best Hyperparameters:
# - LSTM Layers: 3
# - LSTM Units per Layer: [256, 64, 64]
# - Dropout Rates: [0.2, 0.2, 0.1]
#
# Epoch 1/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.5634 - mean_absolute_percentage_error: 162.7081 - root_mean_squared_error: 0.7371 - val_loss: 0.3790 - val_mean_absolute_percentage_error: 317.6884 - val_root_mean_squared_error: 0.6032
# Epoch 2/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.4795 - mean_absolute_percentage_error: 163.7601 - root_mean_squared_error: 0.6814 - val_loss: 0.3481 - val_mean_absolute_percentage_error: 254.7610 - val_root_mean_squared_error: 0.5794
# Epoch 3/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.4090 - mean_absolute_percentage_error: 148.5424 - root_mean_squared_error: 0.6300 - val_loss: 0.3262 - val_mean_absolute_percentage_error: 475.1001 - val_root_mean_squared_error: 0.5617
# Epoch 4/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.3848 - mean_absolute_percentage_error: 155.1796 - root_mean_squared_error: 0.6113 - val_loss: 0.2931 - val_mean_absolute_percentage_error: 427.9373 - val_root_mean_squared_error: 0.5322
# Epoch 5/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.3497 - mean_absolute_percentage_error: 164.6049 - root_mean_squared_error: 0.5824 - val_loss: 0.2840 - val_mean_absolute_percentage_error: 467.7789 - val_root_mean_squared_error: 0.5238
# Epoch 6/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.3422 - mean_absolute_percentage_error: 167.6031 - root_mean_squared_error: 0.5766 - val_loss: 0.2748 - val_mean_absolute_percentage_error: 529.2286 - val_root_mean_squared_error: 0.5151
# Epoch 7/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.3186 - mean_absolute_percentage_error: 160.2627 - root_mean_squared_error: 0.5557 - val_loss: 0.2907 - val_mean_absolute_percentage_error: 512.8872 - val_root_mean_squared_error: 0.5308
# Epoch 8/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.3314 - mean_absolute_percentage_error: 135.2778 - root_mean_squared_error: 0.5673 - val_loss: 0.2600 - val_mean_absolute_percentage_error: 557.8046 - val_root_mean_squared_error: 0.5013
# Epoch 9/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.3369 - mean_absolute_percentage_error: 152.5607 - root_mean_squared_error: 0.5721 - val_loss: 0.2855 - val_mean_absolute_percentage_error: 725.7692 - val_root_mean_squared_error: 0.5265
# Epoch 10/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.3177 - mean_absolute_percentage_error: 141.1224 - root_mean_squared_error: 0.5562 - val_loss: 0.2863 - val_mean_absolute_percentage_error: 513.9938 - val_root_mean_squared_error: 0.5274
# Epoch 11/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.2947 - mean_absolute_percentage_error: 132.2707 - root_mean_squared_error: 0.5344 - val_loss: 0.2557 - val_mean_absolute_percentage_error: 512.3973 - val_root_mean_squared_error: 0.4978
# Epoch 12/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.3078 - mean_absolute_percentage_error: 124.7714 - root_mean_squared_error: 0.5472 - val_loss: 0.2826 - val_mean_absolute_percentage_error: 644.8948 - val_root_mean_squared_error: 0.5240
# Epoch 13/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.3298 - mean_absolute_percentage_error: 138.9814 - root_mean_squared_error: 0.5667 - val_loss: 0.2532 - val_mean_absolute_percentage_error: 690.2296 - val_root_mean_squared_error: 0.4953
# Epoch 14/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.2963 - mean_absolute_percentage_error: 163.4500 - root_mean_squared_error: 0.5362 - val_loss: 0.2666 - val_mean_absolute_percentage_error: 465.1729 - val_root_mean_squared_error: 0.5084
# Epoch 15/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.3176 - mean_absolute_percentage_error: 141.8640 - root_mean_squared_error: 0.5557 - val_loss: 0.2767 - val_mean_absolute_percentage_error: 540.9457 - val_root_mean_squared_error: 0.5184
# ✅ Hyperparameter tuning complete! Best model saved.
